# %% [markdown]
# Наши данные

# %%
import pandas as pd
import re

pth = '/home/sondors/Documents/price/BERT_NER/csv/Kazakov_241123/Dunlop_character.xlsx'   
df = pd.read_excel(pth, dtype=str)
df
# print(df.keys())
# Out:
#      PRICE_FRNO PRICE_FNAM PRICE_CAID PRICE_CNAM PRICE_TMNO PRICE_TMRK  \
# 0         96794        NaN       8101        NaN       1177     Dunlop
# 1         96794        NaN       8101        NaN       1177     Dunlop
# 2         61852        NaN       8101        NaN       1177     Dunlop
# 3         96794        NaN       8101        NaN       1177     Dunlop
# 4         96794        NaN       8101        NaN       1177     Dunlop
# ...         ...        ...        ...        ...        ...        ...
# 4888      99886        NaN       8101        NaN       1177     Dunlop
# 4889      99886        NaN       8101        NaN       1177     Dunlop
# 4890      99886        NaN       8101        NaN       1177     Dunlop
# 4891      99886        NaN       8101        NaN       1177     Dunlop
# 4892      99886        NaN       8101        NaN       1177     Dunlop
#
#                                              PRICE_NAME            Модель  \
# 0                 13/175/70 Dunlop Winter Maxx WM02 82T  Winter Maxx WM02
# 1                 14/185/65 Dunlop SP Winter Ice 02 90T  SP Winter Ice 02
# 2                   145/65 R15 Dunlop SP Sport 2030 72S     SP Sport 2030
# 3                  15/185/55 Dunlop SP Sport LM705W 86V   SP Sport LM705W
# 4                 15/185/55 Dunlop Winter Maxx WM02 82T  Winter Maxx WM02
# ...                                                 ...               ...
# 4888  R20 275/50 113R XL Dunlop Winter Maxx SJ8 Dunl...   Winter Maxx Sj8
# 4889  R20 285/50 116T XL Dunlop Grandtrek Ice 03 Шип...  Grandtrek Ice 03
# 4890  R21 275/45 110R XL Dunlop Winter Maxx SJ8 Dunl...   Winter Maxx Sj8
# 4891  R21 275/50 113R Dunlop Winter Maxx SJ8 2018 г....   Winter Maxx Sj8
# 4892  R21 295/40 111R Dunlop Winter Maxx SJ8 Dunlop ...   Winter Maxx Sj8
#
#      Ширина шины 135-355 Высота профиля 25-100  ... PRICE_PCOD date  \
# 0                    175                    70  ...        NaN  NaN
# 1                    185                    65  ...        NaN  NaN
# 2                    145                    65  ...     299941  NaN
# 3                    185                    55  ...        NaN  NaN
# 4                    185                    55  ...        NaN  NaN
# ...                  ...                   ...  ...        ...  ...
# 4888                 275                    50  ...     351211  NaN
# 4889                 285                    50  ...     334592  NaN
# 4890                 275                    45  ...     351212  NaN
# 4891                 275                    50  ...     321001  NaN
# 4892                 295                    40  ...     338064  NaN
#
#      PRICE_RSLT                                         kpl     ppl  \
# 0          Auto  Все товары :: Авто :: Шины и диски :: Шины  Dunlop
# 1          Auto  Все товары :: Авто :: Шины и диски :: Шины  Dunlop
# 2          Auto                                        Шины  Dunlop
# 3          Auto  Все товары :: Авто :: Шины и диски :: Шины  Dunlop
# 4          Auto  Все товары :: Авто :: Шины и диски :: Шины  Dunlop
# ...         ...                                         ...     ...
# 4888       Auto                            ШИНЫ :: Легковые  Dunlop
# 4889       Auto                            ШИНЫ :: Легковые  Dunlop
# 4890       Auto                            ШИНЫ :: Легковые  Dunlop
# 4891       Auto                             ШИНЫ :: Дисконт  Dunlop
# 4892       Auto                            ШИНЫ :: Легковые  Dunlop
#
#                                              PRICE_IMGN      PRICE_LOCD  \
# 0     https://avatars.mds.yandex.net/get-mpic/175985...          [8101]
# 1     https://avatars.mds.yandex.net/get-mpic/360912...          [8101]
# 2     https://euro-diski.ru/upload/iblock/fdc/vober1...    [8101, 2211]
# 3     https://avatars.mds.yandex.net/get-mpic/160542...  [8101, 730701]
# 4     https://avatars.mds.yandex.net/get-mpic/523195...          [8101]
# ...                                                 ...             ...
# 4888  https://yourtyres.ru/image/cache/catalog/YML02...          [8101]
# 4889  https://yourtyres.ru/image/cache/catalog/YML02...          [8101]
# 4890  https://yourtyres.ru/image/cache/catalog/YML02...          [8101]
# 4891  https://yourtyres.ru/image/cache/catalog/YML02...          [8101]
# 4892  https://yourtyres.ru/image/cache/catalog/YML02...          [8101]
#
#                lineNumber PRICE_SALES  PRICE_PLID
# 0     2023-08-13 14:45:35         NaN  1694909112
# 1     2023-06-17 22:31:32         NaN  1709624323
# 2     2023-06-10 18:10:11         NaN  1690240964
# 3     2023-07-29 18:50:34         NaN  1721676084
# 4     2023-07-29 18:50:34         NaN  1751414146
# ...                   ...         ...         ...
# 4888  2023-04-11 23:23:07         NaN  1690200307
# 4889  2023-04-11 23:23:07         NaN  1690196208
# 4890  2023-04-11 23:23:07         NaN  1690204352
# 4891  2023-04-13 19:23:11         NaN  1690200170
# 4892  2023-04-11 23:23:07         NaN  1690188012
#
# [4893 rows x 37 columns]

# %%
print(df.keys())
# Out:
# Index(['PRICE_FRNO', 'PRICE_FNAM', 'PRICE_CAID', 'PRICE_CNAM', 'PRICE_TMNO',
#        'PRICE_TMRK', 'PRICE_NAME', 'Модель', 'Ширина шины 135-355',
#        'Высота профиля 25-100', 'Диаметр 12-24 R',
#        'Индекснагрузкиискорости54-200+буква', 'XL', 'Unnamed: 13',
#        'PRICE_PRCN', 'PRICE_VERT', 'PRICE_PARAM', 'PRICE_PRDS', 'PRICE_DPRN',
#        'PRICE_BARCODE', 'PRICE_PTYP', 'PRICE_PROMO', 'PRICE_CURR',
#        'PRICE_LOCA', 'PRICE_WARR', 'PRICE_NOTE', 'PRICE_DTSH', 'PRICE_PCOD',
#        'date', 'PRICE_RSLT', 'kpl', 'ppl', 'PRICE_IMGN', 'PRICE_LOCD',
#        'lineNumber', 'PRICE_SALES', 'PRICE_PLID'],
#       dtype='object')

# %%
def process_text(input_text):
    def separate_letters_and_numbers(input_text):
        # Используем регулярное выражение для поиска сочетаний букв и цифр
        pattern = re.compile(r'(\D+|\d+)')
        
        # Используем findall для нахождения всех сочетаний
        matches = pattern.findall(input_text)
        # Возвращаем строку с пробелами между буквами и цифрами
        return ' '.join(matches)

    processed_text = separate_letters_and_numbers(input_text)    
    processed_text = processed_text.replace("|", " | ")
    processed_text = processed_text.replace("(", " ( ")
    processed_text = processed_text.replace(")", " ) ")
    processed_text = processed_text.replace("[", " [ ")
    processed_text = processed_text.replace("]", " ] ")
    # Убираем повторяющиеся пробелы
    processed_text = re.sub(r'  +', ' ', processed_text)
    return processed_text

def create_bio_tags(row):
    name = str(row['offer'])
    width = str(row['width'])
    height = str(row['height'])
    radius = str(row['radius'])
    brand = row['brand']
    line = str(row['line'])
    v_ind = str(row['v_ind'])

    # Создаем пустой список для хранения тегов
    tags = ['O'] * len(name.split())
    Begin_line = True
    Begin_v_ind = True
    Begin_radius = True
    # Проверяем каждое слово в наименовании и устанавливаем соответствующий тег
    for i, word in enumerate(name.split()):
        if word == '/':
            continue
        
        #   width
        if word == width:
            tags[i] = 'B-width'
            width = width.replace(word,"")

        #   height
        elif word == height:
            tags[i] = 'B-height'
            height = height.replace(word,"")

        #   radius    
        elif word.upper() in radius.upper():
            if radius.replace(" ","") == "":
                continue

            if Begin_radius:
                tags[i] = 'B-radius'
                Begin_radius = False
            else:
                tags[i] = 'I-radius'
            radius = radius.replace(word.lower(),"").replace(word.upper(),"")

        #   brand
        elif word in brand:
            tags[i] = 'B-brand'

        #   v_ind
        elif word.upper() in v_ind.upper():
            if v_ind.replace(" ","") == "":
                continue

            if Begin_v_ind:
                tags[i] = 'B-v_ind'
                Begin_v_ind = False
            else:
                tags[i] = 'I-v_ind'  
            v_ind = v_ind.replace(word.lower(),"").replace(word.upper(),"")  

        #   line
        elif word.upper() in line.upper() or re.sub(r"[^a-zA-Zа-яА-Я]","", word.upper().replace("СПОРТ", "SPORT")) in line.upper():
            if len(re.sub(r"[^a-zA-Zа-яА-Я]","", word.upper().replace("СПОРТ", "SPORT")))<3 and Begin_line:
                continue
            if line.replace(" ","") == "":
                continue
            
            if Begin_line:
                tags[i] = 'B-line'
                Begin_line = False
            else:
                tags[i] = 'I-line'
            line = line.replace(word,"")

    # Собираем теги в строку
    return ','.join(tags)

def change_columns(df):   
    new_df = pd.DataFrame()

    df = df.rename(columns={'PRICE_NAME': 'offer'})
    df = df[df['offer'].notna()]

    new_df['offer'] = df['offer']
    new_df['width'] = df['Ширина шины 135-355']
    new_df['height'] = df['Высота профиля 25-100']
    new_df['radius'] = df['Диаметр 12-24 R']
    new_df['v_ind'] = df['Индекснагрузкиискорости54-200+буква']
    new_df['brand'] = df['ppl']
    new_df['line'] = df['Модель']

    new_df['offer'] = new_df['offer'].apply(process_text)
    new_df['brand'] = new_df['offer'].apply(extract_Dunlop)
    new_df['BIO_Tags'] = new_df.apply(create_bio_tags, axis=1)
    return new_df

def extract_Dunlop(text):
    brands = re.findall(r'Dunlop|DUNLOP|Дунлоп|dunlop|ДАНЛОП|Данлоп|ДУНЛОП|Данлуп|ДАНЛУП', text)
    return brands

new_df = change_columns(df)
new_df
# Out:
#                                                   offer width height radius  \
# 0           13 / 175 / 70 Dunlop Winter Maxx WM 02 82 T   175     70    R13
# 1            14 / 185 / 65 Dunlop SP Winter Ice 02 90 T   185     65    R14
# 2               145 / 65 R 15 Dunlop SP Sport 2030 72 S   145     65    R15
# 3           15 / 185 / 55 Dunlop SP Sport LM 705 W 86 V   185     55    R15
# 4           15 / 185 / 55 Dunlop Winter Maxx WM 02 82 T   185     55    R15
# ...                                                 ...   ...    ...    ...
# 4888  R 20 275 / 50 113 R XL Dunlop Winter Maxx SJ 8...   275     50    R20
# 4889  R 20 285 / 50 116 T XL Dunlop Grandtrek Ice 03...   285     50    R20
# 4890  R 21 275 / 45 110 R XL Dunlop Winter Maxx SJ 8...   275     45    R21
# 4891  R 21 275 / 50 113 R Dunlop Winter Maxx SJ 8 20...   275     50    R21
# 4892  R 21 295 / 40 111 R Dunlop Winter Maxx SJ 8 Du...   295     40    R21
#
#      v_ind             brand              line  \
# 0      82T          [Dunlop]  Winter Maxx WM02
# 1      90T          [Dunlop]  SP Winter Ice 02
# 2      72S          [Dunlop]     SP Sport 2030
# 3      86V          [Dunlop]   SP Sport LM705W
# 4      82T          [Dunlop]  Winter Maxx WM02
# ...    ...               ...               ...
# 4888  113R  [Dunlop, Dunlop]   Winter Maxx Sj8
# 4889  116T  [Dunlop, Dunlop]  Grandtrek Ice 03
# 4890  110R  [Dunlop, Dunlop]   Winter Maxx Sj8
# 4891  113R  [Dunlop, Dunlop]   Winter Maxx Sj8
# 4892  111R  [Dunlop, Dunlop]   Winter Maxx Sj8
#
#                                                BIO_Tags
# 0     B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# 1     B-radius,O,B-width,O,B-height,B-brand,O,B-line...
# 2     B-width,O,B-height,B-radius,I-radius,B-brand,O...
# 3     B-radius,O,B-width,O,B-height,B-brand,O,B-line...
# 4     B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# ...                                                 ...
# 4888  B-radius,I-radius,B-width,O,B-height,B-v_ind,I...
# 4889  B-radius,I-radius,B-width,O,B-height,B-v_ind,I...
# 4890  B-radius,I-radius,B-width,O,B-height,B-v_ind,I...
# 4891  B-radius,I-radius,B-width,O,B-height,B-v_ind,I...
# 4892  B-radius,I-radius,B-width,O,B-height,B-v_ind,I...
#
# [4893 rows x 8 columns]

# %%
new_df.to_csv('/home/sondors/Documents/price/BERT_NER/csv/Kazakov_241123/разметка/Dunlop.csv', sep=';',index=False)

# %%
dict(new_df.line.value_counts())
# Out:
# {'SP Sport Maxx 050 plus': 543,
#  'Winter Maxx Sj8': 446,
#  'Winter Maxx WM02': 350,
#  'Direzza DZ102': 295,
#  'Grandtrek Ice 03': 285,
#  'SP Winter Ice 03': 259,
#  'Winter Maxx WM01': 246,
#  'SP Sport LM705W': 224,
#  'Grandtrek PT3': 222,
#  'Grandtrek AT5': 216,
#  'SP Winter Ice 02': 170,
#  'Grandtrek Ice 02': 142,
#  'SP VAN01': 140,
#  'SP Sport Maxx 050': 110,
#  'SP Sport Maxx 050 plus SUV': 88,
#  'Grandtrek MT2': 62,
#  'SP Winter VAN01': 60,
#  'SP Sport LM705': 59,
#  'SP Touring R1': 59,
#  'Grandtrek AT20': 59,
#  'SP Sport Maxx 050 plus RunFlat': 57,
#  'SP Sport FM800': 44,
#  'SP Sport Maxx 050 RunFlat': 37,
#  'SP Sport 01': 33,
#  'Winter Maxx WM01 Runflat': 31,
#  'SP Winter ICE 02': 30,
#  'Grandtrek AT25': 29,
#  'Grandtrek AT3': 28,
#  'SP Sport Maxx GT 600 Runflat': 26,
#  'SP Sport Maxx GT': 24,
#  'Winter Maxx WM02 Runflat': 24,
#  'Grandtrek AT22': 24,
#  'Graspic DS3': 21,
#  'Grandtrek ST20': 21,
#  'SP Winter Sport 3D': 19,
#  'SP Touring T1': 18,
#  'SP Sport 270': 18,
#  'SP Winter Sport 3D Runflat': 18,
#  'SP Sport Maxx TT': 17,
#  'SP Sport Maxx RT': 16,
#  'Grandtrek ST30': 16,
#  'SP LT30': 16,
#  'Enasave EC300 plus': 16,
#  'SP Sport 2030': 16,
#  'SP Sport Maxx GT RunFlat': 15,
#  'GrandTrek SJ6 ': 15,
#  'Grandtrek AT30': 14,
#  'Enasave EC300': 14,
#  'Direzza DZ101': 13,
#  'SP Sport Maxx GT 600': 12,
#  'Grandtrek PT1': 12,
#  'Grandtrek AT23': 11,
#  'SP Winter Sport 500': 11,
#  'SP Winter Sport 400': 11,
#  'SP Winter Ice 01': 10,
#  'SP Sport LM703': 10,
#  'SP Winter Sport 4D': 7,
#  'SP Sport 2050': 7,
#  'SP LT36': 6,
#  'SP Sport LM704': 6,
#  'SP LT30A': 6,
#  'SP Sport Maxx A1': 5,
#  'SP Winter Response': 5,
#  'Winter Sport 5': 5,
#  'Ice Touch': 5,
#  'SP Sport 9000': 4,
#  'Grandtrek AT5 SUV': 4,
#  'Grandtrek Ice 03 SUV': 3,
#  'SP Sport 2050M': 3,
#  'SP QuattroMaxx': 3,
#  'Grandtrek PT5A': 2,
#  'MAX GEEI': 2,
#  'SP Sport 5000': 2,
#  'SP Sport 01 RunFlat': 2,
#  'Winter Maxx SJ8': 2,
#  'Grandtrek PT3 SUV': 2,
#  'SP Sport 230': 2,
#  'SP StreetResponse': 2,
#  'SP Winter Sport M3': 2,
#  'SP Winter Sport W400': 2,
#  'SP Sport Maxx TT RunFlat': 1,
#  'SP Sport FastResponse': 1,
#  'SP252': 1,
#  'SP Sport Maxx 050 SUV': 1,
#  'SP Touring R1 Runflat': 1,
#  'SP320': 1,
#  'SP Sport Maxx TT ': 1,
#  'SP Sport Maxx 050 RunFlat ': 1,
#  'SP Sport 7000': 1,
#  'SP 446': 1,
#  'SP 346 plus': 1,
#  'Grandtrek SJ6': 1,
#  'Graspic DS2': 1,
#  'Touring A/S': 1,
#  'GrandTrek ST1': 1,
#  'GrandTrek SJ5': 1,
#  'Grandtrek PT5': 1,
#  'Grandtrek MT1': 1,
#  'Digi-Tyre Eco EC 201': 1,
#  'SP Sport 2020E': 1,
#  'Sport SP270': 1,
#  'Grandtrek PT2': 1}

# %%
index = 4891
example = dict(new_df.iloc[index])
print(example['offer'],'\n')
offer = example['offer'].split()
BIO_Tags = example['BIO_Tags'].split(',')

for i in range(len(offer)):
    print(f"{offer[i]}: {BIO_Tags[i]}")
# Out:
# R 21 275 / 50 113 R Dunlop Winter Maxx SJ 8 2018 г.в. Dunlop Winter Maxx SJ 8
#
# R: B-radius
# 21: I-radius
# 275: B-width
# /: O
# 50: B-height
# 113: B-v_ind
# R: I-v_ind
# Dunlop: B-brand
# Winter: B-line
# Maxx: I-line
# SJ: I-line
# 8: I-line
# 2018: I-line
# г.в.: O
# Dunlop: B-brand
# Winter: O
# Maxx: O
# SJ: I-line
# 8: I-line

# %%
example
# Out:
# {'offer': 'R 21 275 / 50 113 R Dunlop Winter Maxx SJ 8 2018 г.в. Dunlop Winter Maxx SJ 8',
#  'width': '275',
#  'height': '50',
#  'radius': 'R21',
#  'v_ind': '113R',
#  'brand': ['Dunlop', 'Dunlop'],
#  'line': 'Winter Maxx Sj8',
#  'BIO_Tags': 'B-radius,I-radius,B-width,O,B-height,B-v_ind,I-v_ind,B-brand,B-line,I-line,I-line,I-line,I-line,O,B-brand,O,O,I-line,I-line'}

# %%
example
# Out:
# {'offer': 'R 21 275 / 50 113 R Dunlop Winter Maxx SJ 8 2018 г.в. Dunlop Winter Maxx SJ 8',
#  'width': '275',
#  'height': '50',
#  'radius': 'R21',
#  'v_ind': '113R',
#  'brand': ['Dunlop', 'Dunlop'],
#  'line': 'Winter Maxx Sj8',
#  'BIO_Tags': 'B-radius,I-radius,B-width,O,B-height,B-v_ind,I-v_ind,B-brand,B-line,I-line,I-line,I-line,I-line,O,B-brand,O,O,I-line,I-line'}

# %%
label2id = {'B-width': 1,
            'B-height': 2, 
            'B-radius': 3, 
            'I-radius': 4,
            'B-brand': 5, 
            'B-line': 6, 
            'I-line': 7,
            'B-v_ind': 8,
            'I-v_ind': 9,
            'O': 0}
    
id2label = {1: 'B-width',
            2: 'B-height', 
            3: 'B-radius', 
            4: 'I-radius',
            5: 'B-brand', 
            6: 'B-line', 
            7: 'I-line',
            8: 'B-v_ind',
            9: 'I-v_ind',
            0: 'O'}
