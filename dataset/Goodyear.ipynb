# %% [markdown]
# Наши данные

# %%
import pandas as pd
import re

pth = '/home/sondors/Documents/price/BERT_NER/csv/Kazakov_241123/Goodyear_character.xlsx'   
df = pd.read_excel(pth, dtype=str)
df
# print(df.keys())
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Комментарии  \
# 0          96794        NaN       8101        NaN       7312         NaN
# 1          96794        NaN       8101        NaN       7312         NaN
# 2          96794        NaN       8101        NaN       7312         NaN
# 3          96794        NaN       8101        NaN       7312         NaN
# 4          96794        NaN       8101        NaN       7312         NaN
# ...          ...        ...        ...        ...        ...         ...
# 10732      96794        NaN       8101        NaN       7312         NaN
# 10733      99886        NaN       8101        NaN       7312         NaN
# 10734      99886        NaN       8101        NaN       7312         NaN
# 10735      99886        NaN       8101        NaN       7312         NaN
# 10736      96794        NaN       8101        NaN       7312         NaN
#
#                                             Наименование  \
# 0        15/185/60 Goodyear Ultra Grip Ice Arctic 88T XL
# 1           15/195/55 Goodyear Ultra Grip Ice Arctic 85T
# 2         15/195/55 Goodyear UltraGrip Performance + 85H
# 3                   15/195/60 Goodyear Eagle Sport 2 88V
# 4           15/195/60 Goodyear Ultra Grip Ice Arctic 88T
# ...                                                  ...
# 10732  R21 27545 Goodyear UltraGrip Arctic 2 SUV 110T XL
# 10733  R21 305/30 104V XL FP Goodyear Ultra Grip Perf...
# 10734  R22 265/35 102V XL FP Goodyear Ultra Grip Perf...
# 10735  R22 275/40 107V XL FP Goodyear Ultra Grip Perf...
# 10736  ULTRAGRIP ICE 2+ Шина Автошина GOODYEAR 215/50...
#
#                                Модель Ширина шины Высота профиля  ...  \
# 0                UltraGrip Ice Arctic         185             60  ...
# 1                UltraGrip Ice Arctic         195             55  ...
# 2          UltraGrip Performance plus         195             55  ...
# 3                       Eagle Sport 2         195             60  ...
# 4                UltraGrip Ice Arctic         195             60  ...
# ...                               ...         ...            ...  ...
# 10732          UltraGrip Arctic 2 SUV         275             45  ...
# 10733     UltraGrip Performance Gen-1         305             30  ...
# 10734  UltraGrip Performance plus SUV         265             35  ...
# 10735      UltraGrip Performance plus         275             40  ...
# 10736            UltraGrip Ice 2 Plus         215             50  ...
#
#       Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0             NaN         NaN        Auto
# 1             NaN         NaN        Auto
# 2             NaN         NaN        Auto
# 3             NaN         NaN        Auto
# 4             NaN         NaN        Auto
# ...           ...         ...         ...
# 10732      580144         NaN        Auto
# 10733      547515         NaN        Auto
# 10734      574449         NaN        Auto
# 10735      574235         NaN        Auto
# 10736         NaN      Active        Auto
#
#                                       Unnamed: 29       Unnamed: 30  \
# 0      Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# 1      Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# 2      Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# 3      Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# 4      Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# ...                                           ...               ...
# 10732  Все товары :: Авто :: Шины и диски :: Шины          Goodyear
# 10733                            ШИНЫ :: Легковые          Goodyear
# 10734                            ШИНЫ :: Легковые          Goodyear
# 10735                            ШИНЫ :: Легковые          Goodyear
# 10736  Все товары :: Авто :: Шины и диски :: Шины  ULTRAGRIP ICE 2+
#
#                                              Unnamed: 31  \
# 0      https://avatars.mds.yandex.net/get-mpic/523653...
# 1      https://avatars.mds.yandex.net/get-mpic/186608...
# 2      https://avatars.mds.yandex.net/get-mpic/411318...
# 3      https://avatars.mds.yandex.net/get-mpic/526127...
# 4      https://avatars.mds.yandex.net/get-mpic/186608...
# ...                                                  ...
# 10732  https://avatars.mds.yandex.net/get-mpic/449071...
# 10733  https://yourtyres.ru/image/cache/catalog/YML02...
# 10734  https://yourtyres.ru/image/cache/catalog/YML02...
# 10735  https://yourtyres.ru/image/cache/catalog/YML02...
# 10736  https://avatars.mds.yandex.net/get-mpic/523596...
#
#                 Unnamed: 32          Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0                    [8101]  2023-04-13 06:37:43         NaN  1695030863
# 1                    [8101]  2023-04-17 02:18:33         NaN  1702659559
# 2            [8101, 829805]  2023-08-15 01:15:45         NaN  1694135823
# 3      [8101, 8104, 740202]  2023-06-08 23:34:57         NaN  1694532959
# 4                    [8101]  2023-04-22 15:58:44         NaN  1707510375
# ...                     ...                  ...         ...         ...
# 10732                [8101]  2023-07-29 18:50:34         NaN  1745872056
# 10733                [8101]  2023-04-11 23:23:07         NaN  1690203343
# 10734                [8101]  2023-04-11 23:23:07         NaN  1690198252
# 10735                [8101]  2023-04-11 23:23:07         NaN  1690184952
# 10736                [8101]  2023-08-16 06:43:09         NaN  1776323894
#
# [10737 rows x 36 columns]

# %%
print(df.keys())
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Комментарии', 'Наименование', 'Модель', 'Ширина шины',
#        'Высота профиля', 'Диаметр', 'Индекс нагрузки и скорости', 'XL',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
df['Unnamed: 30'].value_counts()
# Out:
# Goodyear                                                      7844
# GOODYEAR                                                      1554
# GoodYear                                                      1263
# Goodyear (Гудиер)                                               31
# Goodyear (Гудеар)                                               24
# goodyear                                                         5
# VECTOR 4SEASONS GEN-3                                            1
# UltraGrip Ice 2                                                  1
# UltraGrip 8 Performance                                          1
# UltraGrip Performance SUV Gen-1                                  1
# втехнике.рф                                                      1
# Шины Goodyear Eagle F1 Asymmetric 5 245/35 R20 95Y RunFlat       1
# Шины Goodyear Eagle F1 Asymmetric 5 245/35R20 95Y Runflat        1
# ULTRAGRIP ICE 2+                                                 1
# Name: Unnamed: 30, dtype: int64

# %%
def process_text(input_text):
    def separate_letters_and_numbers(input_text):
        # Используем регулярное выражение для поиска сочетаний букв и цифр
        pattern = re.compile(r'(\D+|\d+)')
        
        # Используем findall для нахождения всех сочетаний
        matches = pattern.findall(input_text)
        # Возвращаем строку с пробелами между буквами и цифрами
        return ' '.join(matches)

    processed_text = separate_letters_and_numbers(input_text)    
    processed_text = processed_text.replace("|", " | ")
    processed_text = processed_text.replace("(", " ( ")
    processed_text = processed_text.replace(")", " ) ")
    processed_text = processed_text.replace("[", " [ ")
    processed_text = processed_text.replace("]", " ] ")
    # Убираем повторяющиеся пробелы
    processed_text = re.sub(r'  +', ' ', processed_text)
    return processed_text

def create_bio_tags(row):
    name = str(row['offer'])
    width = str(row['width'])
    height = str(row['height'])
    radius = str(row['radius'])
    brand = row['brand']
    line = str(row['line'])
    v_ind = str(row['v_ind'])

    # Создаем пустой список для хранения тегов
    tags = ['O'] * len(name.split())
    Begin_line = True
    Begin_v_ind = True
    Begin_radius = True
    # Проверяем каждое слово в наименовании и устанавливаем соответствующий тег
    for i, word in enumerate(name.split()):
        if word == '/':
            continue
        
        #   width
        if word == width:
            tags[i] = 'B-width'
            width = width.replace(word,"")

        #   height
        elif word == height:
            tags[i] = 'B-height'
            height = height.replace(word,"")

        #   radius    
        elif word.upper() in radius.upper():
            if radius.replace(" ","") == "":
                continue

            if Begin_radius:
                tags[i] = 'B-radius'
                Begin_radius = False
            else:
                tags[i] = 'I-radius'
            radius = radius.replace(word.lower(),"").replace(word.upper(),"")

        #   brand
        elif word in brand:
            tags[i] = 'B-brand'

        #   v_ind
        elif word.upper() in v_ind.upper():
            if v_ind.replace(" ","") == "":
                continue

            if Begin_v_ind:
                tags[i] = 'B-v_ind'
                Begin_v_ind = False
            else:
                tags[i] = 'I-v_ind'  
            v_ind = v_ind.replace(word.lower(),"").replace(word.upper(),"")  

        #   line
        elif word.upper() in line.upper() or re.sub(r"[^a-zA-Zа-яА-Я]","", word.upper().replace("СПОРТ", "SPORT")) in line.upper():
            if len(re.sub(r"[^a-zA-Zа-яА-Я]","", word.upper().replace("СПОРТ", "SPORT")))<3 and Begin_line:
                continue
            if line.replace(" ","") == "":
                continue
            
            if Begin_line:
                tags[i] = 'B-line'
                Begin_line = False
            else:
                tags[i] = 'I-line'
            line = line.replace(word,"")

    # Собираем теги в строку
    return ','.join(tags)

def change_columns(df):   
    new_df = pd.DataFrame()

    df = df.rename(columns={'Наименование': 'offer'})
    df = df[df['offer'].notna()]

    new_df['offer'] = df['offer']
    new_df['width'] = df['Ширина шины']
    new_df['height'] = df['Высота профиля']
    new_df['radius'] = df['Диаметр']
    new_df['v_ind'] = df['Индекс нагрузки и скорости']
    new_df['brand'] = df['Unnamed: 30']
    new_df['line'] = df['Модель']

    new_df['offer'] = new_df['offer'].apply(process_text)
    new_df['brand'] = new_df['offer'].apply(extract_Gislaved)
    new_df['BIO_Tags'] = new_df.apply(create_bio_tags, axis=1)
    return new_df

def extract_Gislaved(text):
    brands = re.findall(r'Goodyear|GOODYEAR|GoodYear|goodyear|goodYear|Гудиер|Гудеар|ГУДИЕР|ГУДЕАР|гудиер|гудеар', text)
    return brands

new_df = change_columns(df)
new_df
# Out:
#                                                    offer width height radius  \
# 0      15 / 185 / 60 Goodyear Ultra Grip Ice Arctic 8...   185     60     15
# 1       15 / 195 / 55 Goodyear Ultra Grip Ice Arctic 85T   195     55     15
# 2      15 / 195 / 55 Goodyear UltraGrip Performance +...   195     55     15
# 3               15 / 195 / 60 Goodyear Eagle Sport 2 88V   195     60     15
# 4       15 / 195 / 60 Goodyear Ultra Grip Ice Arctic 88T   195     60     15
# ...                                                  ...   ...    ...    ...
# 10732  R 21 27545 Goodyear UltraGrip Arctic 2 SUV 110...   275     45     21
# 10733  R 21 305 / 30 104V XL FP Goodyear Ultra Grip P...   305     30     21
# 10734  R 22 265 / 35 102V XL FP Goodyear Ultra Grip P...   265     35     22
# 10735  R 22 275 / 40 107V XL FP Goodyear Ultra Grip P...   275     40     22
# 10736  ULTRAGRIP ICE 2+ Шина Автошина GOODYEAR 215 / ...   215     50     19
#
#       v_ind       brand                            line  \
# 0       88T  [Goodyear]            UltraGrip Ice Arctic
# 1       85T  [Goodyear]            UltraGrip Ice Arctic
# 2       85H  [Goodyear]      UltraGrip Performance plus
# 3       88V  [Goodyear]                   Eagle Sport 2
# 4       88T  [Goodyear]            UltraGrip Ice Arctic
# ...     ...         ...                             ...
# 10732  110T  [Goodyear]          UltraGrip Arctic 2 SUV
# 10733  104V  [Goodyear]     UltraGrip Performance Gen-1
# 10734  102V  [Goodyear]  UltraGrip Performance plus SUV
# 10735  107V  [Goodyear]      UltraGrip Performance plus
# 10736   93T  [GOODYEAR]            UltraGrip Ice 2 Plus
#
#                                                 BIO_Tags
# 0      B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# 1      B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# 2      B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# 3      B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# 4      B-radius,O,B-width,O,B-height,B-brand,B-line,I...
# ...                                                  ...
# 10732  B-radius,I-radius,O,B-brand,B-line,I-line,I-ra...
# 10733  B-radius,I-radius,B-width,O,B-height,B-v_ind,O...
# 10734  B-radius,I-radius,B-width,O,B-height,B-v_ind,O...
# 10735  B-radius,I-radius,B-width,O,B-height,B-v_ind,O...
# 10736  B-line,I-line,I-line,O,O,B-brand,B-width,O,B-h...
#
# [10737 rows x 8 columns]

# %%
new_df.to_csv('/home/sondors/Documents/price/BERT_NER/csv/Kazakov_241123/разметка/Goodyear.csv', sep=';',index=False)

# %%
dict(new_df.line.value_counts())
# 'Wrangler A/T Adventure'
# 'Wrangler A/T Adventure Kevlar'
# Out:
# {'UltraGrip Performance plus': 937,
#  'UltraGrip Ice Arctic': 522,
#  'Eagle F1 Asymmetric 5': 493,
#  'UltraGrip Ice 2': 440,
#  'UltraGrip Ice SUV Gen-1': 417,
#  'Vector 4Seasons Gen-3': 395,
#  'UltraGrip Arctic 2': 360,
#  'UltraGrip Ice Arctic SUV': 340,
#  'Eagle F1 Asymmetric 2': 329,
#  'Eagle F1 Asymmetric 3': 327,
#  'UltraGrip Performance Gen-1': 315,
#  'EfficientGrip Performance 2': 303,
#  'UltraGrip Arctic 2 SUV': 221,
#  'UltraGrip Performance plus SUV': 218,
#  'EfficientGrip Performance': 211,
#  'Eagle F1 Asymmetric 3 SUV': 210,
#  'Eagle F1 SuperSport': 192,
#  'Eagle Sport TZ': 188,
#  'UltraGrip Performance SUV Gen-1': 157,
#  'UltraGrip Performance': 150,
#  'UltraGrip 9 plus': 137,
#  'EfficientGrip SUV': 131,
#  'UltraGrip Ice 2 Plus': 130,
#  'Wrangler A/T Adventure': 129,
#  'Eagle F1 Asymmetric 3 RunFlat': 126,
#  'Vector 4Seasons Gen-2': 126,
#  'UltraGrip Cargo': 126,
#  'UltraGrip 8 Performance': 125,
#  'EfficientGrip 2 SUV': 121,
#  'Eagle F1 Asymmetric 6': 115,
#  'UltraGrip Ice SUV': 108,
#  'Eagle F1 Asymmetric 2 RunFlat': 105,
#  'Eagle Sport': 100,
#  'UltraGrip Ice Plus': 94,
#  'EfficientGrip': 92,
#  'Wrangler HP All weather': 92,
#  'UltraGrip 600': 90,
#  'EfficientGrip RunFlat': 85,
#  'Eagle F1 Asymmetric SUV': 82,
#  'UltraGrip Performance plus RunFlat': 77,
#  'UltraGrip Plus SUV': 72,
#  'Wrangler A/T Adventure Kevlar': 70,
#  'EfficientGrip Cargo 2': 62,
#  'UltraGrip': 62,
#  'UltraGrip Performance 2 RunFlat': 56,
#  'Vector 4Seasons Cargo': 56,
#  'UltraGrip 9': 53,
#  'Vector 4Seasons Gen-1': 53,
#  'UltraGrip 2 Cargo': 52,
#  'Vector 4Seasons': 49,
#  'Excellence RunFlat': 46,
#  'Eagle Sport 2': 46,
#  'Vector 4Seasons SUV Gen-2': 46,
#  'Eagle F1 Asymmetric': 45,
#  'Vector 4Seasons Gen-3 SUV': 44,
#  'Eagle F1 Asymmetric SUV AT': 40,
#  'UltraGrip 8 Performance RunFlat': 40,
#  'Eagle NCT5 RunFlat': 39,
#  'EfficientGrip Compact': 39,
#  'Eagle Touring': 36,
#  'UltraGrip RunFlat': 34,
#  'Eagle UltraGrip GW-3 RunFlat': 32,
#  'UltraGrip Performance Gen-1 RunFlat': 32,
#  'Eagle Sport TZ SUV': 30,
#  'Vector 4Seasons Gen-2 RunFlat': 28,
#  'Eagle F1 SuperSport R': 27,
#  'Eagle F1 Asymmetric SUV RunFlat': 26,
#  'EfficientGrip Cargo': 24,
#  'UltraGrip 2 SUV': 23,
#  'Excellence': 23,
#  'Eagle LS2': 23,
#  'UltraGrip 8': 22,
#  'Eagle F1 Asymmetric 2 SUV': 20,
#  'UltraGrip Performance 2': 19,
#  'Vector 4Seasons Gen-3 RunFlat': 19,
#  'Wrangler DuraTrac': 19,
#  'Eagle LS2 RunFlat': 18,
#  'Vector 2 Cargo': 18,
#  'UltraGrip Performance RunFlat': 17,
#  'UltraGrip Performance SUV': 17,
#  'EfficientGrip Performance 2 SUV': 16,
#  'EfficientGrip Performance RunFlat': 16,
#  'UltraGrip SUV Plus': 15,
#  'Eagle F1 Supercar': 15,
#  'Eagle F1 Asymmetric 5 RunFlat': 15,
#  'UltraGrip Ice': 14,
#  'Duramax Gen-2': 13,
#  'Eagle UltraGrip GW-3': 12,
#  'Eagle Sport RunFlat': 11,
#  'UltraGrip 8 RunFlat': 11,
#  'UltraGrip SUV RunFlat': 10,
#  'EfficientGrip Performance 2 RunFlat': 10,
#  'Eagle NCT5': 9,
#  'UltraGrip SUV': 9,
#  'Wrangler Duratrac': 8,
#  'Marathon Cargo': 8,
#  'Vector Cargo': 8,
#  'Eagle F1 Asymmetric RunFlat': 8,
#  'UltraGrip 500': 7,
#  'Eagle F1 SuperSport RS': 7,
#  'Wrangler MT/R Kevlar': 7,
#  'Wrangler UltraGrip': 6,
#  'UltraGrip Cargo RunFlat': 6,
#  'Wrangler SR/A': 5,
#  'Optigrip': 4,
#  'Wrangler AT/SA Plus': 4,
#  'UltraGrip Ice 2 Plus RunFlat': 4,
#  'Wrangler HP All weather RunFlat': 4,
#  'Eagle RS-A': 4,
#  'EfficientGrip 2': 4,
#  'Eagle Sport SUV': 4,
#  'UltraGrip Ice 2 RunFlat': 3,
#  'UltraGrip Ice WRT': 3,
#  'DuraGrip': 3,
#  'Vector 4Seasons SUV': 3,
#  'Eagle F1 Asymmetric 3 SUV RunFlat': 3,
#  'Eagle F1 GSD3': 3,
#  'UltraGrip Arctic 2 RunFlat': 2,
#  'Cargo G26': 2,
#  'Wrangler AT/SA': 2,
#  'Wrangler AT/S': 2,
#  'Wrangler AT/R': 2,
#  'Vector 4Seasons Gen-1 RunFlat': 2,
#  'UltraGrip Ice SUV Gen-1 RunFlat': 2,
#  'UltraGrip Ice SUV RunFlat': 2,
#  'EfficientGrip Performance SUV': 2,
#  'UltraGrip Extreme': 2,
#  'UltraGrip Arctic 2 SUV RunFlat': 2,
#  'UltraGrip 6': 2,
#  'Wrangler MT/R': 2,
#  'Ultra High Performance Plus': 2,
#  'Eagle F1 Asymmetric 2 SUV RunFlat': 2,
#  'UltraGrip Ice Gen-1': 2,
#  'UltraGrip SUV GEN-1': 2,
#  'Kmax S': 2,
#  'Wrangler': 1,
#  'Wrangler HP All weather SUV': 1,
#  'Wrangler F1': 1,
#  'Kmax D': 1,
#  'Kmax T': 1,
#  'OffRoad ORD': 1,
#  'Vector 4Seasons RunFlat': 1,
#  'Eagle F1 Supercar RunFlat': 1,
#  'Duramax': 1,
#  'UltraGrip Performance SUV Gen-5': 1,
#  'Eagle F1 SuperCar': 1,
#  'UltraGrip Plus': 1,
#  'Eagle F1 GSD3 RunFlat': 1,
#  'Eagle F1': 1,
#  'Cargo G90': 1,
#  'Eagle F1 SuperSport R RunFlat': 1}

# %%
index = 10000
example = dict(new_df.iloc[index])
print(example['offer'],'\n')
offer = example['offer'].split()
BIO_Tags = example['BIO_Tags'].split(',')

for i in range(len(offer)):
    print(f"{offer[i]}: {BIO_Tags[i]}")
# Out:
# Goodyear Wrangler All-Terrain Adventure 205 / 70 R 15 100T XL
#
# Goodyear: B-brand
# Wrangler: B-line
# All-Terrain: O
# Adventure: I-line
# 205: B-width
# /: O
# 70: B-height
# R: B-radius
# 15: I-radius
# 100T: B-v_ind
# XL: O

# %%
example
# Out:
# {'offer': 'Goodyear Wrangler All-Terrain Adventure 205 / 70 R 15 100T XL',
#  'width': '205',
#  'height': '70',
#  'radius': '15',
#  'v_ind': '100T',
#  'brand': ['Goodyear'],
#  'line': 'Wrangler A/T Adventure',
#  'BIO_Tags': 'B-brand,B-line,O,I-line,B-width,O,B-height,B-radius,I-radius,B-v_ind,O'}

# %%
label2id = {'B-width': 1,
            'B-height': 2, 
            'B-radius': 3, 
            'I-radius': 4,
            'B-brand': 5, 
            'B-line': 6, 
            'I-line': 7,
            'B-v_ind': 8,
            'I-v_ind': 9,
            'O': 0}
    
id2label = {1: 'B-width',
            2: 'B-height', 
            3: 'B-radius', 
            4: 'I-radius',
            5: 'B-brand', 
            6: 'B-line', 
            7: 'I-line',
            8: 'B-v_ind',
            9: 'I-v_ind',
            0: 'O'}
