# %%
import pandas as pd

# %%
# pth = "/home/sondors/Documents/price/BERT_NER/csv/first_10_rows.xlsx"
pth = "/home/sondors/Documents/price/BERT_NER/csv/list1.xlsx"
df = pd.read_excel(pth)

clms = ['PRICE_FRNO', 
        'PRICE_FNAM', 
        'PRICE_CAID', 
        'PRICE_CNAM',  
        'PRICE_TMNO', 
        'PRICE_PRCN', 
        'PRICE_VERT', 
        'PRICE_PCOD', 
        'date', 
        'PRICE_IMGN', 
        'PRICE_LOCD', 
        'lineNumber',
        'PRICE_PRDS',
        'PRICE_DPRN',
        'PRICE_PTYP',
        'PRICE_PROMO',
        'PRICE_CURR',
        'PRICE_LOCA',
        'PRICE_WARR',
        'PRICE_RSLT',
        'PRICE_PLID',
        'PRICE_SALES',
        'PRICE_DTSH',
        'PRICE_BARCODE',
        'комментарий',
        'kpl',
        'PRICE_PARAM',
        'PRICE_NOTE']

clms_hz = ['kpl',
           'PRICE_NOTE',
           'PRICE_PARAM']

df = df.drop(columns=clms + clms_hz)
df
# Out:
#                                               PRICE_NAME Ширина Высота Радиус  \
# 0            10,5/31 R15 Bridgestone Dueler A/T 001 109S    NaN    NaN    NaN
# 1      12067 Bridgestone Автошина R20 275/50 Bridgest...    275     50     20
# 2      12088 BRIDGESTONE Автошина R20 255/50 Bridgest...    255     50     20
# 3          13/175/70 Bridgestone Ice Cruiser 7000S 82T ш    175     70     17
# 4      13602 BRIDGESTONE Автошина R18 275/35 Bridgest...    275     35     18
# ...                                                  ...    ...    ...    ...
# 23143  Бриджстоун 2657015 T 112 AT001, BRIDGESTONE 12...    NaN    NaN    NaN
# 23144  Бриджстоун 2753518 S 95 VRX, BRIDGESTONE 8393 ...    NaN    NaN    NaN
# 23145  Бриджстоун 315/70r22.5 R249 Tl 152/154 L/M Рул...    315     70     15
# 23146    шинаBridgestone LT245/75R16 120Q Dueler M/T 674    245     75     16
# 23147  Автошина Bridgestone Continental Blizzak Ice 2...    225     50     17
#
#       Инд. Скорост   XL  RFT            Линейка          ppl
# 0             109S  NaN  NaN             Dueler  Bridgestone
# 1             113R   XL  NaN      Blizzak DM-V2  Bridgestone
# 2             109T   XL  NaN      Blizzak DM-V2  Bridgestone
# 3              82S  NaN  NaN  Ice Cruiser 7000S  Bridgestone
# 4              95S  NaN  NaN        Blizzak Ice  Bridgestone
# ...            ...  ...  ...                ...          ...
# 23143          NaN  NaN  NaN                NaN  Bridgestone
# 23144          NaN  NaN  NaN        Blizzak VRX  Bridgestone
# 23145      152/154  NaN  NaN                NaN  BRIDGESTONE
# 23146         120Q  NaN  NaN             Dueler  Bridgestone
# 23147          98T  NaN  NaN        Blizzak Ice  Bridgestone
#
# [23148 rows x 9 columns]

# %%
pth1 = "/home/sondors/Documents/price/BERT_NER/csv/Прайс_Колобокс_Шины_2018-07-07 (XLS).xls"
df1 = pd.read_excel(pth1)
df1
# Out:
#          Размер  Ширина  Профиль Диаметр Сезонность  Шип  Артикул  \
# 0           NaN     NaN      NaN     NaN        NaN  NaN      NaN
# 1     175/65R14   175.0     65.0      14       Зима   Да  2230300
# 2     175/70R13   175.0     70.0      13       Зима   Да  9160786
# 3     205/55R16   205.0     55.0      16       Зима   Да  9160797
# 4     215/65R16   215.0     65.0      16       Зима   Да  9160801
# ...         ...     ...      ...     ...        ...  ...      ...
# 3697  285/60R18   285.0     60.0      18       Зима  Нет    F3459
# 3698  285/60R18   285.0     60.0      18       Зима  Нет    R1571
# 3699  285/60R18   285.0     60.0      18       Лето  Нет    F3706
# 3700  295/35R21   295.0     35.0      21       Зима  Нет    F3960
# 3701  295/40R20   295.0     40.0      20       Зима  Нет    F3961
#
#            Код 1С Марка (бренд)                                   Наименование
# 0             NaN           NaN                                            NaN
# 1     УТ-00004306         Amtel         Amtel 175/65R14 82Q Nordmaster (В-228)
# 2     УТ-00037677       Avatyre                   Avatyre 175/70R13 82Q Freeze
# 3     УТ-00037681       Avatyre                   Avatyre 205/55R16 91T Freeze
# 4     УТ-00037683       Avatyre                   Avatyre 215/65R16 98T Freeze
# ...           ...           ...                                            ...
# 3697  УТ-00007132      Yokohama  Yokohama 285/60R18 116Q Geolandar  I/T-S G073
# 3698  УТ-00099428      Yokohama          Yokohama 285/60R18 116Q IceGuard G075
# 3699  УТ-00010449      Yokohama  Yokohama 285/60R18 116V Geolandar H/T G94 (B)
# 3700  УТ-00007138      Yokohama  Yokohama 295/35R21 107Q Geolandar  I/T-S G073
# 3701  УТ-00007140      Yokohama  Yokohama 295/40R20 110Q Geolandar  I/T-S G073
#
# [3702 rows x 10 columns]

# %%
pth2 = "/home/sondors/Documents/price/BERT_NER/csv/легковая_резина.xls"
df2 = pd.read_excel(pth2)
df2
# Out:
#                RN                                  Наименование  Остаток  \
# 0     87309330811   Bontyre  33/12.5/15  Q 108 Stalker M/T лев.        2
# 1     87309333516  Bontyre  33/12.5/15  Q 108 Stalker M/T прав.        2
# 2     86282044720      Cargo S  SATOYA  185/75/16  R  104/102 C       14
# 3     86959420208         HIFLY  185/60/15  T 84 Win-turi 215          2
# 4     86959429194         HIFLY  205/55/16  H 91 Win-turi 215         40
# ...           ...                                           ...      ...
# 2278  87356383200    Формула  235/60/18  T 107 FORMULA ICE XL         20
# 2279  86189860570          Формула  245/40/18  Y 97  Energy  XL        2
# 2280  86734325574                 Ханкук  235/65/18  T 106 RW08        4
# 2281  85611349914                      Я-245-1 к    215/90/15 C        3
# 2282  85769662829                   131  Форвард  Бр  195/80/16        2
#
#       Резерв  Заказ Цена_руб Распр  Происх Сезон    Марка             Модель  \
# 0          0    NaN     7579   Нет  Импорт  Лето  Bontyre   Stalker M/T лев.
# 1          0    NaN     7579   Нет  Импорт  Лето  Bontyre  Stalker M/T прав.
# 2          0    NaN     2950   Нет  Отечка  Зима   SATOYA            Cargo S
# 3          0    NaN     2477   Нет  Импорт  Зима    HIFLY       Win-turi 215
# 4          0    NaN     3044   Нет  Импорт  Зима    HIFLY       Win-turi 215
# ...      ...    ...      ...   ...     ...   ...      ...                ...
# 2278       4    NaN     6433   Нет  Импорт  Зима  Формула     FORMULA ICE XL
# 2279       0    NaN     6200   Нет  Импорт  Лето  Формула         Energy  XL
# 2280       0    NaN     5788   Нет  Импорт  Зима   Ханкук               RW08
# 2281       6    NaN     2877   Нет  Отечка  Лето    НК.ШЗ          Я-245-1 к
# 2282       0    NaN        0   Нет  Отечка  Лето       Бр       131  Форвард
#
#       Диам    Шир  Проф  Шип            Скор Код_произв     РРЦ
# 0       15   33.0  12.5  Нет               Q        NaN     NaN
# 1       15   33.0  12.5  Нет               Q        NaN     NaN
# 2       16  185.0  75.0   Да               R        NaN  3100.0
# 3       15  185.0  60.0   Да               T   300H3021     NaN
# 4       16  205.0  55.0   Да               H   300H3002     NaN
# ...    ...    ...   ...  ...             ...        ...     ...
# 2278    18  235.0  60.0   Да               T    2783500     NaN
# 2279    18  245.0  40.0  Нет               Y    2400500  7340.0
# 2280    18  235.0  65.0  Нет               T    1015873  6370.0
# 2281    15  215.0  90.0  Нет  @скорость рез.    1230001  3160.0
# 2282    16  195.0  80.0  Нет  @скорость рез.        NaN     NaN
#
# [2283 rows x 18 columns]

# %%
pth3 = "/home/sondors/Documents/price/BERT_NER/csv/грузовая_резина.xls"
df3 = pd.read_excel(pth3)
df3
# Out:
#               RN                                       Наименование  Остаток  \
# 0    87331600987  HIFLY 12.00R20 HH301 TT PR18 154/149 K Универс...       40
# 1    87331603269  HIFLY 12.00R20 HH313 TT PR18 154/149 K Ведущая...       40
# 2    87333640401  HIFLY 315/70R22.5 HH102 TL PR20 154/150 L Руле...        8
# 3    87333648335  HIFLY 315/70R22.5 HH308A TL PR20 154/150 L Вед...       16
# 4    87333658287  HIFLY 315/80R22.5 HH102 TL PR20 156/152 L Руле...        6
# ..           ...                                                ...      ...
# 260  86218196458                 9.00R20 О-40-БМ НК.ШЗ 14 140/137 J       40
# 261  86615568006                9.00-16 Я-324А Волж.ШЗ 10 123 A7 TT        9
# 262  13472826001                      9.00-20 ВЛ-45 Волж.ШЗ 6 111 A       16
# 263  86583412728       9.5R32 DN-104 VOLTYRE AGRO Волж.ШЗ 112 A8 TT        4
# 264  86519839128    9.5-32 DN-104В VOLTYRE AGRO Волж.ШЗ 8 117 A6 TT        4
#
#      Резерв  Заказ  Цена_руб Распр  Происх    Марка                Модель  \
# 0         0    NaN     17500   Нет  Импорт    HIFLY                 HH301
# 1         0    NaN     18620   Нет  Импорт    HIFLY                 HH313
# 2         0    NaN     13450   Нет  Импорт    HIFLY                 HH102
# 3         0    NaN     15000   Нет  Импорт    HIFLY                HH308A
# 4         6    NaN     13900   Нет  Импорт    HIFLY                 HH102
# ..      ...    ...       ...   ...     ...      ...                   ...
# 260       7    NaN      8014   Нет  Отечка    НК.ШЗ               О-40-БМ
# 261       2    NaN      4959   Нет  Отечка  Волж.ШЗ                Я-324А
# 262       0    NaN      4844   Нет  Отечка  Волж.ШЗ                 ВЛ-45
# 263       0    NaN     11738   Нет  Отечка  Волж.ШЗ   DN-104 VOLTYRE AGRO
# 264       0    NaN     11154   Нет  Отечка  Волж.ШЗ  DN-104В VOLTYRE AGRO
#
#           Размер  Диам    Шир      Проф   Код_произв      РРЦ
# 0       12.00R20    20  12.00  @профиль          NaN  19581.0
# 1       12.00R20    20  12.00  @профиль          NaN  20149.0
# 2    315/70R22.5  22.5    315        70          NaN  14659.0
# 3    315/70R22.5  22.5    315        70          NaN  15120.0
# 4    315/80R22.5  22.5    315        80          NaN  14360.0
# ..           ...   ...    ...       ...          ...      ...
# 260      9.00R20    20   9.00  @профиль      1330006   8010.0
# 261      9.00-16    16   9.00  @профиль  11214071251   5350.0
# 262      9.00-20    20   9.00  @профиль     82110911   5230.0
# 263       9.5R32    32    9.5  @профиль  11214821121  12360.0
# 264       9.5-32    32    9.5  @профиль  11214721171  12610.0
#
# [265 rows x 16 columns]

# %%
pth4 = "/home/sondors/Documents/price/BERT_NER/csv/диски.xls"
df4 = pd.read_excel(pth4)
df4
# Out:
#               RN                                       Наименование  Остаток  \
# 0    86577408905   ASTERRO  11,75\R22,5 10*335 ET135  d281  [2239D]        4
# 1    86141042272  Gold Wheel  ВАЗ-08  5,0\R13 4*98 ET40  d58,6  ...        1
# 2    86253193239  Jantsa  13,00\R22,5 10*285,75 ET133,5  d220  [...        2
# 3    85833694504        Jantsa  6,5\R15 10*225 ET135  d176  [65155]       11
# 4    85875831667  KFZ  8114  6,0\R15 4*100 ET48  d54  [85875831667]        8
# ..           ...                                                ...      ...
# 933  86743970014  ТЗСК  Toyota Camry/Corolla  6,5\R16 5*114,3 ET...       40
# 934  86750080584  ТЗСК  ВАЗ-08  5,5\R13 4*98 ET35  d58,5  Серо-з...        1
# 935  86530673475  ТЗСК  ВАЗ-08  5,5\R13 4*98 ET35  d58,6  Черный...        1
# 936  86750082303  ТЗСК  ВАЗ-10  5,5\R14 4*98 ET35  d58,5  Серо-з...        2
# 937  86530673972  ТЗСК  ВАЗ-10  5,5\R14 4*98 ET35  d58,6  Черный...        1
#
#      Резерв  Заказ Цена_руб Распр Тип_диска Происх       Марка        Модель  \
# 0         0    NaN     5701   Нет     Груз.   Имп.     ASTERRO  @модель дис.
# 1         0    NaN      590   Нет    Штамп.   Имп.  Gold Wheel  @модель дис.
# 2         0    NaN  7641,65    Да     Груз.   Имп.      Jantsa  @модель дис.
# 3         0    NaN  3165,09   Нет     Груз.   Имп.      Jantsa  @модель дис.
# 4         0    NaN     1989   Нет    Штамп.   Имп.         KFZ          8114
# ..      ...    ...      ...   ...       ...    ...         ...           ...
# 933       0    NaN     1587   Нет    Штамп.  Отеч.        ТЗСК  @модель дис.
# 934       0    NaN      800   Нет    Штамп.  Отеч.        ТЗСК  @модель дис.
# 935       0    NaN      788   Нет    Штамп.  Отеч.        ТЗСК  @модель дис.
# 936       0    NaN      838   Нет    Штамп.  Отеч.        ТЗСК  @модель дис.
# 937       0    NaN      814   Нет    Штамп.  Отеч.        ТЗСК  @модель дис.
#
#      Диам    Шир  Отв     PCD       DPCD  Вылет Ступица   Код_произв     РРЦ
# 0    22,5  11,75   10     335  @dublePCD    135     281        2239D  6807.0
# 1      13    5,0    4      98  @dublePCD     40    58,6          NaN   620.0
# 2    22,5  13,00   10  285,75  @dublePCD  133,5     220       130257  7600.0
# 3      15    6,5   10     225  @dublePCD    135     176        65155     NaN
# 4      15    6,0    4     100  @dublePCD     48      54  85875831667  2190.0
# ..    ...    ...  ...     ...        ...    ...     ...          ...     ...
# 933    16    6,5    5   114,3  @dublePCD     45    60,1  86743970014  1750.0
# 934    13    5,5    4      98  @dublePCD     35    58,5  86750080584   880.0
# 935    13    5,5    4      98  @dublePCD     35    58,6  86530673475   870.0
# 936    14    5,5    4      98  @dublePCD     35    58,5  86750082303   920.0
# 937    14    5,5    4      98  @dublePCD     35    58,6  86530673972   900.0
#
# [938 rows x 20 columns]
