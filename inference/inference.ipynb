# %% [markdown]
# ### Загрузка нейронок

# %%
from transformers import CanineTokenizer, CanineForTokenClassification, BertTokenizer, BertForTokenClassification, AutoTokenizer, LukeForTokenClassification, pipeline
import pandas as pd
import re

def load_model_CANINE(model_pth, device, label2id, id2label):
    tokenizer = CanineTokenizer.from_pretrained(model_pth)
    model = CanineForTokenClassification.from_pretrained(model_pth, 
                                            num_labels=len(id2label),
                                            id2label=id2label,
                                            label2id=label2id)
    return tokenizer, model.to(device)

def load_model_BERT(model_pth, device, label2id, id2label):
    model = BertForTokenClassification.from_pretrained(model_pth, 
                                        num_labels=len(id2label),
                                        id2label=id2label,
                                        label2id=label2id)
    tokenizer = BertTokenizer.from_pretrained(model_pth)
    return tokenizer, model.to(device)

def load_model_LUKE(model_pth, device, label2id, id2label):
    model = LukeForTokenClassification.from_pretrained(model_pth, 
                                        num_labels=len(id2label),
                                        id2label=id2label,
                                        label2id=label2id)
    tokenizer = AutoTokenizer.from_pretrained(model_pth)
    return tokenizer, model.to(device)

def inference(offer, model, tokenizer, device):
    pipe = pipeline(task="ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple", device=device)
    return pipe(offer)

def brand_line_width_height_radius(result):
    # Создаем словари для каждой сущности
    entities = {}
    for item in result:
        entity_group = item['entity_group']
        word = item['word']
        score = item['score']
        if score > 0.7:
            if entity_group in entities:
                entities[entity_group].append(word)
            else:
                entities[entity_group] = [word]

    for key, value in entities.items():
        entities[key] = ''.join(value)
    return entities

def apply_on_df(model, tokenizer, df, device, column = 'offer'):
    for index, row in df.iterrows():
        offer = row[column]
        result = inference(offer, model, tokenizer, device)
        entities = brand_line_width_height_radius(result)

        # Заполнение DataFrame
        df.at[index, 'brand_pred'] = entities.get('brand', '')
        df.at[index, 'width_pred'] = entities.get('width', '')
        df.at[index, 'height_pred'] = entities.get('height', '')
        df.at[index, 'radius_pred'] = entities.get('radius', '')
        df.at[index, 'line_pred'] = entities.get('line', '')
        df.at[index, 'v_ind_pred'] = entities.get('v_ind', '')
    return df

label2id = {'B-width': 1,
            'B-height': 2, 
            'B-radius': 3, 
            'I-radius': 4,
            'B-brand': 5, 
            'B-line': 6, 
            'I-line': 7,
            'B-v_ind': 8,
            'I-v_ind': 9,
            'O': 0}
    
id2label = {1: 'B-width',
            2: 'B-height', 
            3: 'B-radius', 
            4: 'I-radius',
            5: 'B-brand', 
            6: 'B-line', 
            7: 'I-line',
            8: 'B-v_ind',
            9: 'I-v_ind',
            0: 'O'}

device = "cpu"

# model_pth = "/home/sondors/CANINE-epoch_4"
# tokenizer_CANINE, model_CANINE = load_model_CANINE(model_pth, device, label2id, id2label)

model_pth = "/home/sondors/luke-base-epoch_5"
tokenizer, model = load_model_LUKE(model_pth, device, label2id, id2label)

# %% [markdown]
# ### Загрузка данных

# %%
# pth = "/home/sondors/Documents/price/BERT_NER/csv_to_label/Gislaved.xlsx"
# pth = "/home/sondors/Documents/price/BERT_NER/csv_to_label/Nordman.xlsx"
# pth = "/home/sondors/Documents/price/BERT_NER/csv_to_label/Pirelli.xlsx"
# pth = "/home/sondors/Documents/price/BERT_NER/csv_to_label/Yokohama.xlsx"
pth = "/home/sondors/Documents/price/BERT_NER/csv_to_label/Кама.xlsx"
df_original = pd.read_excel(pth, dtype=str)
df = pd.DataFrame()
df['PRICE_NAME'] = df_original['PRICE_NAME']
# df['PRICE_NAME'] = df_original['Unnamed: 6'] # Pirelli

pth_dst = "/home/sondors/Documents/price/BERT_NER/csv_to_label/luke-base-241123/Кама_Igor241123.xlsx"

df
# Out:
#                                              PRICE_NAME
# 0                             165/70R13 Кама НК-244 79N
# 1                    175/70R13 Кама Alga НК-531 82T шип
# 2                         175/70R13 Кама НК-531 82T шип
# 3             175/80R16 Кама И-511 88Q шип (без камеры)
# 4                       185/60R14 КАМА-365 (НК-241) 82H
# ...                                                 ...
# 6066  Автошина КАМА 365 LT (НК-243) 185/75 R16С 104/...
# 6067                       135/80 R12 Кама-503 68Q шип.
# 6068     Шина летняя R16C 185/75 104/102N Кама Euro-131
# 6069     Автошина КАМА 365 LT (НК-243) 175 R16С 98/96 N
# 6070                      Kama Euro-518 155/65 R13 73 T
#
# [6071 rows x 1 columns]

# %%
df_original
# Out:
#      PRICE_FRNO PRICE_FNAM PRICE_CAID PRICE_CNAM PRICE_TMNO Brand  \
# 0         99084        NaN       8101        NaN       4932  Kama
# 1         99084        NaN       8101        NaN       4932  Kama
# 2         99084        NaN       8101        NaN       4932  Kama
# 3         99084        NaN       8101        NaN       4932  Kama
# 4         99084        NaN       8101        NaN       4932  Kama
# ...         ...        ...        ...        ...        ...   ...
# 6066      96794        NaN       8101        NaN       4932  Kama
# 6067      96794        NaN       8101        NaN       4932  Kama
# 6068      96794        NaN       8101        NaN       4932  Kama
# 6069      96794        NaN       8101        NaN       4932  Kama
# 6070      96794        NaN       8101        NaN       4932  Kama
#
#                                              PRICE_NAME Unnamed: 7 Unnamed: 8  \
# 0                             165/70R13 Кама НК-244 79N        NaN        NaN
# 1                    175/70R13 Кама Alga НК-531 82T шип        NaN        NaN
# 2                         175/70R13 Кама НК-531 82T шип        NaN        NaN
# 3             175/80R16 Кама И-511 88Q шип (без камеры)        NaN        NaN
# 4                       185/60R14 КАМА-365 (НК-241) 82H        NaN        NaN
# ...                                                 ...        ...        ...
# 6066  Автошина КАМА 365 LT (НК-243) 185/75 R16С 104/...        185        NaN
# 6067                       135/80 R12 Кама-503 68Q шип.        NaN        NaN
# 6068     Шина летняя R16C 185/75 104/102N Кама Euro-131        185        NaN
# 6069     Автошина КАМА 365 LT (НК-243) 175 R16С 98/96 N        NaN        NaN
# 6070                      Kama Euro-518 155/65 R13 73 T        NaN        NaN
#
#      Unnamed: 9  ... PRICE_PCOD    date PRICE_RSLT  \
# 0           NaN  ...        NaN  Active       Auto
# 1           NaN  ...        NaN  Active       Auto
# 2           NaN  ...        NaN     NaN       Auto
# 3           NaN  ...        NaN     NaN       Auto
# 4           NaN  ...        NaN     NaN       Auto
# ...         ...  ...        ...     ...        ...
# 6066        NaN  ...        NaN     NaN       Auto
# 6067        NaN  ...        NaN  Active       Auto
# 6068        NaN  ...        NaN     NaN       Auto
# 6069        NaN  ...        NaN     NaN       Auto
# 6070        NaN  ...        NaN     NaN       Auto
#
#                                              kpl   ppl  \
# 0                                           Шины   NaN
# 1                                           Шины   NaN
# 2                                           Шины   NaN
# 3                                           Шины   NaN
# 4                                           Шины   NaN
# ...                                          ...   ...
# 6066  Все товары :: Авто :: Шины и диски :: Шины  КАМА
# 6067  Все товары :: Авто :: Шины и диски :: Шины  КАМА
# 6068  Все товары :: Авто :: Шины и диски :: Шины  КАМА
# 6069  Все товары :: Авто :: Шины и диски :: Шины  КАМА
# 6070  Все товары :: Авто :: Шины и диски :: Шины  КАМА
#
#                                              PRICE_IMGN  \
# 0     https://zavgar.ru/uploads/catalog_items/images...
# 1     https://zavgar.ru/uploads/catalog_items/images...
# 2                                                   NaN
# 3     https://zavgar.ru/uploads/catalog_items/images...
# 4     https://zavgar.ru/uploads/catalog_items/images...
# ...                                                 ...
# 6066  https://avatars.mds.yandex.net/get-mpic/448422...
# 6067  https://avatars.mds.yandex.net/get-mpic/522193...
# 6068  https://avatars.mds.yandex.net/get-mpic/542530...
# 6069  https://avatars.mds.yandex.net/get-mpic/448422...
# 6070  https://avatars.mds.yandex.net/get-mpic/124668...
#
#                             PRICE_LOCD           lineNumber  \
# 0           [8101, 832132, 1403, 2002]  2023-08-16 15:25:16
# 1                               [8101]  2023-08-09 08:45:04
# 2                               [8101]  2022-11-25 12:53:27
# 3     [8101, 3319, 1403, 2812, 719811]  2023-05-30 06:10:51
# 4                               [8101]  2023-07-27 10:40:31
# ...                                ...                  ...
# 6066                            [8101]  2023-05-31 19:52:55
# 6067                            [8101]  2023-08-15 01:15:45
# 6068                            [8101]  2023-04-13 06:37:43
# 6069                            [8101]  2023-05-24 14:21:51
# 6070    [8101, 7107, 2211, 1713, 9759]  2023-04-13 06:37:43
#
#                                       PRICE_SALES  PRICE_PLID
# 0     Продажа от 2х штук; меньше по согласованию.  1622539920
# 1     Продажа от 2х штук; меньше по согласованию.  1628982103
# 2     Продажа от 2х штук; меньше по согласованию.  1627952538
# 3     Продажа от 2х штук; меньше по согласованию.  1651213808
# 4     Продажа от 2х штук; меньше по согласованию.  1622530518
# ...                                           ...         ...
# 6066                                          NaN  1696364312
# 6067                                          NaN  1696350809
# 6068                                          NaN  1696284765
# 6069                                          NaN  1696212025
# 6070                                          NaN  1696105220
#
# [6071 rows x 35 columns]

# %%
def process_text(input_text):
    def separate_letters_and_numbers(input_text):
        # Используем регулярное выражение для поиска сочетаний букв и цифр
        pattern = re.compile(r'(\D+|\d+)')
        
        # Используем findall для нахождения всех сочетаний
        matches = pattern.findall(input_text)
        # Возвращаем строку с пробелами между буквами и цифрами
        return ' '.join(matches)

    processed_text = separate_letters_and_numbers(input_text)    
    processed_text = processed_text.replace("|", " | ")
    processed_text = processed_text.replace("(", " ( ")
    processed_text = processed_text.replace(")", " ) ")
    processed_text = processed_text.replace("[", " [ ")
    processed_text = processed_text.replace("]", " ] ")
    # Убираем повторяющиеся пробелы
    processed_text = re.sub(r'  +', ' ', processed_text)
    return processed_text

def unfuck_offer(text):
    pattern1 = r'(R) (\d+)'
    processed_text = re.sub(pattern1, r'R\2', text)

    pattern2 = r'(\d+) (R)'
    processed_text = re.sub(pattern2, r'\1R', processed_text)

    pattern3 = r'(\/) (\d+)'
    processed_text = re.sub(pattern3, r'/\2', processed_text)

    pattern4 = r'(\d+) (\/)'
    processed_text = re.sub(pattern4, r'\1/', processed_text)

    pattern5 = r'(\\) (\d+)'
    processed_text = re.sub(pattern5, r'\\\2', processed_text)

    pattern6 = r'(\d+) (\\)'
    processed_text = re.sub(pattern6, r'\1\\', processed_text)

    return processed_text

df_CANINE = df.copy()
df_CANINE['PRICE_NAME'] = df_CANINE['PRICE_NAME'].apply(unfuck_offer)

df_BERT = df.copy()
df_BERT['PRICE_NAME'] = df_BERT['PRICE_NAME'].apply(process_text)

print(df_CANINE)
print(df_BERT)
# Out:
#                                              PRICE_NAME
# 0                             165/70R13 Кама НК-244 79N
# 1                    175/70R13 Кама Alga НК-531 82T шип
# 2                         175/70R13 Кама НК-531 82T шип
# 3             175/80R16 Кама И-511 88Q шип (без камеры)
# 4                       185/60R14 КАМА-365 (НК-241) 82H
# ...                                                 ...
# 6066  Автошина КАМА 365 LT (НК-243) 185/75R16С 104/1...
# 6067                        135/80R12 Кама-503 68Q шип.
# 6068     Шина летняя R16C 185/75 104/102N Кама Euro-131
# 6069      Автошина КАМА 365 LT (НК-243) 175R16С 98/96 N
# 6070                       Kama Euro-518 155/65R13 73 T
#
# [6071 rows x 1 columns]
#                                              PRICE_NAME
# 0                       165 / 70 R 13 Кама НК- 244 79 N
# 1              175 / 70 R 13 Кама Alga НК- 531 82 T шип
# 2                   175 / 70 R 13 Кама НК- 531 82 T шип
# 3     175 / 80 R 16 Кама И- 511 88 Q шип ( без камер...
# 4              185 / 60 R 14 КАМА- 365 ( НК- 241 ) 82 H
# ...                                                 ...
# 6066  Автошина КАМА 365 LT ( НК- 243 ) 185 / 75 R 16...
# 6067                  135 / 80 R 12 Кама- 503 68 Q шип.
# 6068  Шина летняя R 16 C 185 / 75 104 / 102 N Кама E...
# 6069  Автошина КАМА 365 LT ( НК- 243 ) 175 R 16 С 98...
# 6070                  Kama Euro- 518 155 / 65 R 13 73 T
#
# [6071 rows x 1 columns]

# %% [markdown]
# ### BERT

# %%
df_BERT = apply_on_df(model, tokenizer, df_BERT, device, column = 'PRICE_NAME')
df_BERT
# Out:
#                                              PRICE_NAME brand_pred width_pred  \
# 0                       165 / 70 R 13 Кама НК- 244 79 N      ��ама        165
# 1              175 / 70 R 13 Кама Alga НК- 531 82 T шип       �ама        175
# 2                   175 / 70 R 13 Кама НК- 531 82 T шип       �ама        175
# 3     175 / 80 R 16 Кама И- 511 88 Q шип ( без камер...      ��ама        175
# 4              185 / 60 R 14 КАМА- 365 ( НК- 241 ) 82 H                   185
# ...                                                 ...        ...        ...
# 6066  Автошина КАМА 365 LT ( НК- 243 ) 185 / 75 R 16...                   185
# 6067                  135 / 80 R 12 Кама- 503 68 Q шип.      ��ама        135
# 6068  Шина летняя R 16 C 185 / 75 104 / 102 N Кама E...                   185
# 6069  Автошина КАМА 365 LT ( НК- 243 ) 175 R 16 С 98...                   175
# 6070                  Kama Euro- 518 155 / 65 R 13 73 T                   155
#
#      height_pred radius_pred     line_pred v_ind_pred
# 0             70        R 13        �- 244         79
# 1             70        R 13      Alga 531         82
# 2             70        R 13       ��- 531         82
# 3             80        R 16   ��- 511 ( )         88
# 4             60        R 14                       82
# ...          ...         ...           ...        ...
# 6066          75        R 16     365 ( 243      104 Q
# 6067          80        R 12         - 503       68 Q
# 6068          75        R 16                      104
# 6069                    R 16       365 243         98
# 6070          65        18 R  Kama Euro- 5         73
#
# [6071 rows x 7 columns]

# %%
def process_digits(txt):
    return re.sub(r"[^0123456789A-Za-z]","", txt)
def process_brand_line(txt):
    return re.sub(r"[^0123456789A-Za-zА-Яа-я/ ]","", txt)

df_original['width_pred'] = df_BERT['width_pred'].apply(process_digits)
df_original['height_pred'] = df_BERT['height_pred'].apply(process_digits)
df_original['radius_pred'] = df_BERT['radius_pred'].apply(process_digits)
df_original['v_ind_pred'] = df_BERT['v_ind_pred'].apply(process_digits)

# df_original['brand_pred'] = df_BERT['brand_pred'].apply(process_brand_line)
df_original['line_pred'] = df_BERT['line_pred'].apply(process_brand_line)

df_original
# Out:
#      PRICE_FRNO PRICE_FNAM PRICE_CAID PRICE_CNAM PRICE_TMNO Brand  \
# 0         99084        NaN       8101        NaN       4932  Kama
# 1         99084        NaN       8101        NaN       4932  Kama
# 2         99084        NaN       8101        NaN       4932  Kama
# 3         99084        NaN       8101        NaN       4932  Kama
# 4         99084        NaN       8101        NaN       4932  Kama
# ...         ...        ...        ...        ...        ...   ...
# 6066      96794        NaN       8101        NaN       4932  Kama
# 6067      96794        NaN       8101        NaN       4932  Kama
# 6068      96794        NaN       8101        NaN       4932  Kama
# 6069      96794        NaN       8101        NaN       4932  Kama
# 6070      96794        NaN       8101        NaN       4932  Kama
#
#                                              PRICE_NAME Unnamed: 7 Unnamed: 8  \
# 0                             165/70R13 Кама НК-244 79N        NaN        NaN
# 1                    175/70R13 Кама Alga НК-531 82T шип        NaN        NaN
# 2                         175/70R13 Кама НК-531 82T шип        NaN        NaN
# 3             175/80R16 Кама И-511 88Q шип (без камеры)        NaN        NaN
# 4                       185/60R14 КАМА-365 (НК-241) 82H        NaN        NaN
# ...                                                 ...        ...        ...
# 6066  Автошина КАМА 365 LT (НК-243) 185/75 R16С 104/...        185        NaN
# 6067                       135/80 R12 Кама-503 68Q шип.        NaN        NaN
# 6068     Шина летняя R16C 185/75 104/102N Кама Euro-131        185        NaN
# 6069     Автошина КАМА 365 LT (НК-243) 175 R16С 98/96 N        NaN        NaN
# 6070                      Kama Euro-518 155/65 R13 73 T        NaN        NaN
#
#      Unnamed: 9  ...                                         PRICE_IMGN  \
# 0           NaN  ...  https://zavgar.ru/uploads/catalog_items/images...
# 1           NaN  ...  https://zavgar.ru/uploads/catalog_items/images...
# 2           NaN  ...                                                NaN
# 3           NaN  ...  https://zavgar.ru/uploads/catalog_items/images...
# 4           NaN  ...  https://zavgar.ru/uploads/catalog_items/images...
# ...         ...  ...                                                ...
# 6066        NaN  ...  https://avatars.mds.yandex.net/get-mpic/448422...
# 6067        NaN  ...  https://avatars.mds.yandex.net/get-mpic/522193...
# 6068        NaN  ...  https://avatars.mds.yandex.net/get-mpic/542530...
# 6069        NaN  ...  https://avatars.mds.yandex.net/get-mpic/448422...
# 6070        NaN  ...  https://avatars.mds.yandex.net/get-mpic/124668...
#
#                             PRICE_LOCD           lineNumber  \
# 0           [8101, 832132, 1403, 2002]  2023-08-16 15:25:16
# 1                               [8101]  2023-08-09 08:45:04
# 2                               [8101]  2022-11-25 12:53:27
# 3     [8101, 3319, 1403, 2812, 719811]  2023-05-30 06:10:51
# 4                               [8101]  2023-07-27 10:40:31
# ...                                ...                  ...
# 6066                            [8101]  2023-05-31 19:52:55
# 6067                            [8101]  2023-08-15 01:15:45
# 6068                            [8101]  2023-04-13 06:37:43
# 6069                            [8101]  2023-05-24 14:21:51
# 6070    [8101, 7107, 2211, 1713, 9759]  2023-04-13 06:37:43
#
#                                       PRICE_SALES  PRICE_PLID width_pred  \
# 0     Продажа от 2х штук; меньше по согласованию.  1622539920        165
# 1     Продажа от 2х штук; меньше по согласованию.  1628982103        175
# 2     Продажа от 2х штук; меньше по согласованию.  1627952538        175
# 3     Продажа от 2х штук; меньше по согласованию.  1651213808        175
# 4     Продажа от 2х штук; меньше по согласованию.  1622530518        185
# ...                                           ...         ...        ...
# 6066                                          NaN  1696364312        185
# 6067                                          NaN  1696350809        135
# 6068                                          NaN  1696284765        185
# 6069                                          NaN  1696212025        175
# 6070                                          NaN  1696105220        155
#
#      height_pred radius_pred v_ind_pred  line_pred
# 0             70         R13         79        244
# 1             70         R13         82   Alga 531
# 2             70         R13         82        531
# 3             80         R16         88      511
# 4             60         R14         82
# ...          ...         ...        ...        ...
# 6066          75         R16       104Q   365  243
# 6067          80         R12        68Q        503
# 6068          75         R16        104
# 6069                     R16         98    365 243
# 6070          65         18R         73  ama uro 5
#
# [6071 rows x 40 columns]

# %%
dict(df_original.radius_pred.value_counts())
# Out:
# {'R16': 2038,
#  'R14': 1241,
#  'R15': 781,
#  'R13': 426,
#  'R': 193,
#  '': 120,
#  'R22': 120,
#  '14': 119,
#  '5R': 108,
#  'R20': 107,
#  '16': 95,
#  '19R14': 93,
#  'R12': 75,
#  'R17': 66,
#  '1R': 59,
#  '15': 42,
#  '13': 39,
#  'R18': 36,
#  '18R13': 36,
#  '19R13': 26,
#  '16R': 25,
#  'R19': 22,
#  '20': 21,
#  '15R': 20,
#  '515R': 16,
#  '19R': 14,
#  'R1419': 12,
#  '14R': 10,
#  '2R': 7,
#  'R24': 5,
#  '12': 4,
#  '18': 4,
#  '1914': 4,
#  '519R': 4,
#  '18R': 4,
#  '6R': 3,
#  '22': 3,
#  'r16': 3,
#  'R21': 3,
#  'R1319': 3,
#  '15R15': 3,
#  '1': 3,
#  '1419': 3,
#  'R1318': 3,
#  'R10': 2,
#  '17': 2,
#  '1414': 2,
#  'r14': 2,
#  'R2016': 2,
#  '1322': 2,
#  '20R': 2,
#  '13R': 2,
#  '19R16': 2,
#  '1919R14': 2,
#  '1813': 2,
#  'R155': 2,
#  'R2012': 1,
#  'r13': 1,
#  'R2018': 1,
#  '10': 1,
#  'r17': 1,
#  'R1322': 1,
#  '165': 1,
#  '19': 1,
#  '16r20': 1,
#  'R2112': 1,
#  'R5': 1,
#  '16R20': 1,
#  '1919R13': 1,
#  '1420': 1,
#  '1514': 1,
#  '22R16': 1,
#  '2016': 1,
#  '14R8': 1,
#  '1218': 1,
#  '1515': 1,
#  '1020': 1,
#  '1620': 1,
#  '6': 1,
#  '1516': 1,
#  '282R': 1,
#  '515': 1,
#  '21': 1,
#  'r15': 1}

# %%
df_original.to_excel(pth_dst)

# %% [markdown]
# ### Проверка CANINE

# %%
# df_CANINE = apply_on_df(model_CANINE, tokenizer_CANINE, df_CANINE, column = 'PRICE_NAME')
# df_CANINE
